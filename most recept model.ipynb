# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijaidatt/Vijaidatt/blob/main/most%20recept%20model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

from tensorflow.keras.models import Sequential

import tensorflow as tf
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix

# Load the dataset
data = pd.read_csv("/combinedataset.csv")

# Separate features and target variable
X = data.drop(columns=['Class'])  # Features
y = data['Class']  # Target variable

# One-hot encode the target variable
y_encoded = pd.get_dummies(y)

# Split the dataset into train and test sets
X_train, X_test, y_train_encoded, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define the neural network model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dense(64, activation='relu'),
    Dense(2, activation='sigmoid')  # 3 units for the 3 classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(X_train_scaled, y_train_encoded, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test_scaled, y_test)
print('Test accuracy:', test_acc)

# Predict classes for the test set
y_pred_prob = model.predict(X_test_scaled)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test.values.argmax(axis=1), y_pred)

print("Confusion Matrix:")
print(conf_matrix)
# Out:
# ...
# Epoch 1/50
# 4/4 [==============================] - 1s 95ms/step - loss: 0.7016 - accuracy: 0.5575 - val_loss: 0.6944 - val_accuracy: 0.5517
# Epoch 2/50
# 4/4 [==============================] - 0s 21ms/step - loss: 0.6240 - accuracy: 0.6460 - val_loss: 0.6991 - val_accuracy: 0.5517
# Epoch 3/50
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5747 - accuracy: 0.6991 - val_loss: 0.7057 - val_accuracy: 0.5172
# Epoch 4/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5440 - accuracy: 0.7434 - val_loss: 0.7164 - val_accuracy: 0.5172
# Epoch 5/50
# 4/4 [==============================] - 0s 22ms/step - loss: 0.5184 - accuracy: 0.7611 - val_loss: 0.7178 - val_accuracy: 0.5172
# Epoch 6/50
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4975 - accuracy: 0.7699 - val_loss: 0.7153 - val_accuracy: 0.5517
# Epoch 7/50
# ...
